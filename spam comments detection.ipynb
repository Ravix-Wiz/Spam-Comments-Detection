# %%
import os
os.chdir('/content/drive/MyDrive/Data Science Projects/Spam Comments Detection in Youtube')

# %%
pwd
# Out:
# '/content/drive/MyDrive/Data Science Projects/Spam Comments Detection in Youtube'

# %%
ls
# Out:
# 'spam comments detection.ipynb'   Youtube02-KatyPerry.csv   Youtube04-Eminem.csv
#  Youtube01-Psy.csv                Youtube03-LMFAO.csv       Youtube05-Shakira.csv

# %%
#import the necessary python libraries

import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB

# %%
data = pd.read_csv('Youtube01-Psy.csv')
print(data.sample(5))
# Out:
#                               COMMENT_ID             AUTHOR  \
# 103    z12li5throi5u540y220chro4nn5gl52k        xSparkShark
# 333    z131idupvn3yhf3mv23dwzhi4pqixvwuw  Александр Федоров
# 289  z12qfpcgnmjcgfqh104cd3fptuuxzxcp0i4          piwnugget
# 329  z13aib0jgoiotfxxi04cj5lgulz3zdfrpew    Stuart Mcdonald
# 325  z12gwldoxpvgjru4004cj3fxyvvvwffjqjg     Ripazha Gaming
#
#                     DATE                                            CONTENT  \
# 103  2014-11-04T12:40:15  Screw this Chinese crap i dont even understand...
# 333  2014-11-13T07:59:33  Look at the pictures, if not difficult http://...
# 289  2014-11-08T10:12:42             YOUTUBE MONEY !!!!!!!!!!!!!!!!!!!!!!!﻿
# 329  2014-11-13T00:38:14  FOLLOW MY COMPANY ON TWITTER  thanks.  https:/...
# 325  2014-11-12T17:37:08         http://hackfbaccountlive.com/?ref=5242575﻿
#
#      CLASS
# 103      0
# 333      1
# 289      0
# 329      1
# 325      1

# %%
#1 indicates the spam and 0 indicates real comments

#only retrieving the required columns of the dataset

data = data[['CONTENT','CLASS']]

print(data.sample(5))
# Out:
#                                                CONTENT  CLASS
# 229                      We pray for you Little Psy ♡﻿      0
# 24                                CHECK OUT MY CHANNEL      1
# 344  everyones back lool this is almost 3 years old...      0
# 78   -----&gt;&gt;&gt;&gt;  https://www.facebook.co...      1
# 242  The Funny Thing Is That this song was made in ...      0
